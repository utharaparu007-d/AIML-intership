# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.0 MB 3.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/10.0 MB 2.5 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/10.0 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/10.0 MB 2.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/10.0 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/10.0 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.9/10.0 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.5/10.0 MB 2.3 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/10.0 MB 2.3 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}

# %%
df = pd.DataFrame(data)

# %%
df.head(1)
# Out:
#     Name  Age
# 0  Alice   25

# %%
df.tail(1)
# Out:
#   Name  Age
# 1  Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False

# %%
df.sort_values('Age')
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df['Age'].apply(lambda x: x + 1)
# Out:
# 0    26
# 1    31
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob']
# Length: 2, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# Name: count, dtype: int64
